# %% [markdown]
# # Early Stopping
#
# * Early stopping is a form of regularization used to **avoid overfitting** on the training dataset.
# * Early stopping keeps track of the validation loss, if the loss stops decreasing for several epochs in a row the training stops.
#
# <img src="https://i.imgur.com/M8ZxF2V.png" width="500"/>

# %% [markdown]
# ## Import

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader

import torchvision
from torchvision import datasets
from torchvision import transforms
from torchvision import models

# %% [markdown]
# ## Dataset & DataLoader

# %%
train_dataset = datasets.MNIST(root='./data', train=True, transform=transforms.ToTensor(), download=True)
valid_dataset = datasets.MNIST(root='./data', train=False, transform=transforms.ToTensor(), download=False)

train_batch_size = 64
test_batch_size = 1000

# Create Dataloader 
train_loader = DataLoader(
    dataset = train_dataset,
    batch_size = train_batch_size,
    shuffle = True
)

valid_loader = DataLoader(
    dataset = valid_dataset,
    batch_size = test_batch_size,
    shuffle = False
)

# %% [markdown]
# ## Simple ANN Model

# %%
class ANN(nn.Module):
    def __init__(self, input_size, hidden_size, num_class):
        super(ANN, self).__init__()
        self.fc1 = nn.Linear(
            in_features=input_size,
            out_features=hidden_size
        )
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(
            in_features=hidden_size,
            out_features=num_class
        )
    
    def forward(self, x):
        output = self.fc1(x)
        output = self.relu(output)
        output = self.fc2(output)
        return output

# %%
input_size = 28 * 28
num_class = 10
hidden_size = 500

model = ANN(
    input_size=input_size,
    hidden_size=hidden_size,
    num_class=num_class 
)

# %% [markdown]
# ## Train & Validation

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# define the tainning routine
def train(model, train_loader, optimizer, loss_function, epoch):

    model.train()
    loss_total = 0

    for idx, (images, labels) in enumerate(train_loader):
        images = images.to(device).view(-1, 28*28)
        labels = labels.to(device)
        
        # zero the parameter gradients
        optimizer.zero_grad()
        output = model(images)
        
        loss = loss_function(output, labels)
        loss_total += loss.item()
        loss.backward()
        
        optimizer.step()
        
    return loss_total / len(train_loader)

# %%
# define the validation routine to evaluate model performance
def valid(model, valid_loader, loss_function):

    model.eval()
    loss_total = 0

    with torch.no_grad():
        for idx, (images, labels) in enumerate(train_loader):
            images = images.to(device).view(-1, 28*28)
            labels = labels.to(device)
            output = model(images)

            loss = loss_function(output, labels)
            loss_total += loss.item()
    return loss_total / len(valid_loader)

# %% [markdown]
# ## Training & Validation Process (w/out Early Stopping)

# %%
import time

# %%
model = ANN(
    input_size=input_size,
    hidden_size=hidden_size,
    num_class=num_class 
)
model.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_function = nn.CrossEntropyLoss()

# %%
init_start = time.time()
for epoch in range(0, 100):
    print(f'Epoch: {epoch}:')
    train_start_time = time.time()
    train_loss = train(model, train_loader, optimizer, loss_function, epoch)

    print("- Spend %.2f seconds on training process" % (time.time() - train_start_time))
    valid_start_time = time.time()
    val_loss = valid(model, valid_loader, loss_function)
    print("- Spend %.2f seconds on validation process" % (time.time() - valid_start_time))
    print('- Training Loss: %.3f, Validation Loss: %.3f' % (train_loss, val_loss))

print('Spend %3.f seconds on entire training process' % (time.time() - init_start))
# Out:
# Epoch: 0:
# - Spend 6.56 seconds on training process
# - Spend 5.55 seconds on validation process
# - Training Loss: 0.262, Validation Loss: 11.437
# Epoch: 1:
# - Spend 6.41 seconds on training process
# - Spend 5.50 seconds on validation process
# - Training Loss: 0.103, Validation Loss: 5.996
# Epoch: 2:
# - Spend 6.37 seconds on training process
# - Spend 5.43 seconds on validation process
# - Training Loss: 0.067, Validation Loss: 4.458
# Epoch: 3:
# - Spend 7.05 seconds on training process
# - Spend 5.48 seconds on validation process
# - Training Loss: 0.047, Validation Loss: 3.413
# Epoch: 4:
# - Spend 6.38 seconds on training process
# - Spend 5.37 seconds on validation process
# - Training Loss: 0.034, Validation Loss: 2.025
# Epoch: 5:
# - Spend 6.09 seconds on training process
# - Spend 5.06 seconds on validation process
# - Training Loss: 0.026, Validation Loss: 1.669
# Epoch: 6:
# - Spend 6.03 seconds on training process
# - Spend 5.08 seconds on validation process
# - Training Loss: 0.018, Validation Loss: 1.104
# Epoch: 7:
# - Spend 5.93 seconds on training process
# - Spend 5.02 seconds on validation process
# - Training Loss: 0.016, Validation Loss: 0.972
# Epoch: 8:
# - Spend 5.93 seconds on training process
# - Spend 4.99 seconds on validation process
# - Training Loss: 0.012, Validation Loss: 0.707
# Epoch: 9:
# - Spend 5.99 seconds on training process
# - Spend 4.96 seconds on validation process
# - Training Loss: 0.009, Validation Loss: 0.656
# Epoch: 10:
# - Spend 5.92 seconds on training process
# - Spend 5.34 seconds on validation process
# - Training Loss: 0.011, Validation Loss: 0.659
# Epoch: 11:
# - Spend 6.43 seconds on training process
# - Spend 5.67 seconds on validation process
# - Training Loss: 0.009, Validation Loss: 0.368
# Epoch: 12:
# - Spend 6.77 seconds on training process
# - Spend 5.83 seconds on validation process
# - Training Loss: 0.005, Validation Loss: 0.360
# Epoch: 13:
# - Spend 7.45 seconds on training process
# - Spend 5.70 seconds on validation process
# - Training Loss: 0.007, Validation Loss: 0.273
# Epoch: 14:
# - Spend 6.55 seconds on training process
# - Spend 5.74 seconds on validation process
# - Training Loss: 0.006, Validation Loss: 1.212
# Epoch: 15:
# - Spend 6.60 seconds on training process
# - Spend 5.78 seconds on validation process
# - Training Loss: 0.005, Validation Loss: 0.216
# Epoch: 16:
# - Spend 6.65 seconds on training process
# - Spend 5.62 seconds on validation process
# - Training Loss: 0.005, Validation Loss: 0.329
# Epoch: 17:
# - Spend 6.49 seconds on training process
# - Spend 5.62 seconds on validation process
# - Training Loss: 0.006, Validation Loss: 0.293
# Epoch: 18:
# - Spend 6.56 seconds on training process
# - Spend 5.72 seconds on validation process
# - Training Loss: 0.006, Validation Loss: 0.718
# Epoch: 19:
# - Spend 6.56 seconds on training process
# - Spend 5.72 seconds on validation process
# - Training Loss: 0.004, Validation Loss: 0.793
# Epoch: 20:
# - Spend 6.64 seconds on training process
# - Spend 5.73 seconds on validation process
# - Training Loss: 0.003, Validation Loss: 0.114
# Epoch: 21:
# - Spend 6.56 seconds on training process
# - Spend 5.71 seconds on validation process
# - Training Loss: 0.004, Validation Loss: 0.202
# Epoch: 22:
# - Spend 6.62 seconds on training process
# - Spend 6.62 seconds on validation process
# - Training Loss: 0.003, Validation Loss: 0.191
# Epoch: 23:
# - Spend 6.63 seconds on training process
# - Spend 5.74 seconds on validation process
# - Training Loss: 0.005, Validation Loss: 0.354
# Epoch: 24:
# - Spend 6.61 seconds on training process
# - Spend 5.70 seconds on validation process
# - Training Loss: 0.003, Validation Loss: 0.034
# Epoch: 25:
# - Spend 6.64 seconds on training process
# - Spend 5.68 seconds on validation process
# - Training Loss: 0.000, Validation Loss: 0.120
# Epoch: 26:
# - Spend 6.61 seconds on training process
# - Spend 5.77 seconds on validation process
# - Training Loss: 0.007, Validation Loss: 0.986
# Epoch: 27:
# - Spend 6.57 seconds on training process
# - Spend 5.66 seconds on validation process
# - Training Loss: 0.006, Validation Loss: 0.134
# Epoch: 28:
# - Spend 6.53 seconds on training process
# - Spend 5.63 seconds on validation process
# - Training Loss: 0.002, Validation Loss: 0.092
# Epoch: 29:
# - Spend 6.45 seconds on training process
# - Spend 5.63 seconds on validation process
# - Training Loss: 0.003, Validation Loss: 0.293
# Epoch: 30:
# - Spend 6.63 seconds on training process
# - Spend 5.68 seconds on validation process
# - Training Loss: 0.006, Validation Loss: 0.168
# Epoch: 31:
# - Spend 6.62 seconds on training process
# - Spend 5.76 seconds on validation process
# - Training Loss: 0.002, Validation Loss: 0.056
# Epoch: 32:
# - Spend 7.38 seconds on training process
# - Spend 5.74 seconds on validation process
# - Training Loss: 0.004, Validation Loss: 0.749
# Epoch: 33:
# - Spend 6.65 seconds on training process
# - Spend 5.75 seconds on validation process
# - Training Loss: 0.003, Validation Loss: 0.527
# Epoch: 34:
# - Spend 6.74 seconds on training process
# - Spend 5.86 seconds on validation process
# - Training Loss: 0.004, Validation Loss: 0.473
# Epoch: 35:
# - Spend 6.72 seconds on training process
# - Spend 5.81 seconds on validation process
# - Training Loss: 0.003, Validation Loss: 0.101
# Epoch: 36:
# - Spend 6.72 seconds on training process
# - Spend 5.79 seconds on validation process
# - Training Loss: 0.002, Validation Loss: 0.048
# Epoch: 37:
# - Spend 6.63 seconds on training process
# - Spend 5.72 seconds on validation process
# - Training Loss: 0.002, Validation Loss: 0.517
# Epoch: 38:
# - Spend 6.59 seconds on training process
# - Spend 5.72 seconds on validation process
# - Training Loss: 0.006, Validation Loss: 0.332
# Epoch: 39:
# - Spend 6.49 seconds on training process
# - Spend 5.74 seconds on validation process
# - Training Loss: 0.003, Validation Loss: 0.285
# Epoch: 40:
# - Spend 6.57 seconds on training process
# - Spend 5.64 seconds on validation process
# - Training Loss: 0.003, Validation Loss: 0.172
# Epoch: 41:
# - Spend 6.50 seconds on training process
# - Spend 6.28 seconds on validation process
# - Training Loss: 0.002, Validation Loss: 0.090
# Epoch: 42:
# - Spend 6.42 seconds on training process
# - Spend 5.56 seconds on validation process
# - Training Loss: 0.001, Validation Loss: 0.323
# Epoch: 43:
# - Spend 6.42 seconds on training process
# - Spend 5.54 seconds on validation process
# - Training Loss: 0.003, Validation Loss: 0.144
# Epoch: 44:
# - Spend 6.44 seconds on training process
# - Spend 5.63 seconds on validation process
# - Training Loss: 0.004, Validation Loss: 0.045
# Epoch: 45:
# - Spend 6.51 seconds on training process
# - Spend 5.57 seconds on validation process
# - Training Loss: 0.001, Validation Loss: 0.028
# Epoch: 46:
# - Spend 6.46 seconds on training process
# - Spend 5.56 seconds on validation process
# - Training Loss: 0.001, Validation Loss: 0.161
# Epoch: 47:
# - Spend 6.41 seconds on training process
# - Spend 5.53 seconds on validation process
# - Training Loss: 0.006, Validation Loss: 0.553
# Epoch: 48:
# - Spend 6.42 seconds on training process
# - Spend 5.56 seconds on validation process
# - Training Loss: 0.003, Validation Loss: 0.217
# Epoch: 49:
# - Spend 6.40 seconds on training process
# - Spend 5.62 seconds on validation process
# - Training Loss: 0.002, Validation Loss: 0.181
# Epoch: 50:
# - Spend 6.49 seconds on training process
# - Spend 5.58 seconds on validation process
# - Training Loss: 0.002, Validation Loss: 0.381
# Epoch: 51:
# - Spend 6.48 seconds on training process
# - Spend 6.26 seconds on validation process
# - Training Loss: 0.003, Validation Loss: 0.174
# Epoch: 52:
# - Spend 6.44 seconds on training process
# - Spend 5.64 seconds on validation process
# - Training Loss: 0.002, Validation Loss: 0.052
# Epoch: 53:
# - Spend 6.45 seconds on training process
# - Spend 5.55 seconds on validation process
# - Training Loss: 0.003, Validation Loss: 0.418
# Epoch: 54:
# - Spend 6.43 seconds on training process
# - Spend 5.57 seconds on validation process
# - Training Loss: 0.003, Validation Loss: 0.235
# Epoch: 55:
# - Spend 6.45 seconds on training process
# - Spend 5.53 seconds on validation process
# - Training Loss: 0.002, Validation Loss: 0.151
# Epoch: 56:
# - Spend 6.39 seconds on training process
# - Spend 5.55 seconds on validation process
# - Training Loss: 0.002, Validation Loss: 0.131
# Epoch: 57:
# - Spend 6.49 seconds on training process
# - Spend 5.55 seconds on validation process
# - Training Loss: 0.004, Validation Loss: 0.236
# Epoch: 58:
# - Spend 6.41 seconds on training process
# - Spend 5.53 seconds on validation process
# - Training Loss: 0.002, Validation Loss: 0.058
# Epoch: 59:
# - Spend 6.14 seconds on training process
# - Spend 5.19 seconds on validation process
# - Training Loss: 0.001, Validation Loss: 0.241
# Epoch: 60:
# - Spend 6.15 seconds on training process
# - Spend 5.15 seconds on validation process
# - Training Loss: 0.004, Validation Loss: 0.016
# Epoch: 61:
# - Spend 6.63 seconds on training process
# - Spend 5.07 seconds on validation process
# - Training Loss: 0.000, Validation Loss: 0.004
# Epoch: 62:
# - Spend 5.93 seconds on training process
# - Spend 5.02 seconds on validation process
# - Training Loss: 0.000, Validation Loss: 0.001
# Epoch: 63:
# - Spend 5.96 seconds on training process
# - Spend 5.03 seconds on validation process
# - Training Loss: 0.006, Validation Loss: 0.176
# Epoch: 64:
# - Spend 5.87 seconds on training process
# - Spend 5.04 seconds on validation process
# - Training Loss: 0.002, Validation Loss: 0.028
# Epoch: 65:
# - Spend 5.93 seconds on training process
# - Spend 4.94 seconds on validation process
# - Training Loss: 0.001, Validation Loss: 0.635
# Epoch: 66:
# - Spend 5.89 seconds on training process
# - Spend 5.02 seconds on validation process
# - Training Loss: 0.004, Validation Loss: 0.357
# Epoch: 67:
# - Spend 5.93 seconds on training process
# - Spend 5.01 seconds on validation process
# - Training Loss: 0.001, Validation Loss: 0.048
# Epoch: 68:
# - Spend 6.14 seconds on training process
# - Spend 5.19 seconds on validation process
# - Training Loss: 0.000, Validation Loss: 0.019
# Epoch: 69:
# - Spend 6.04 seconds on training process
# - Spend 5.07 seconds on validation process
# - Training Loss: 0.004, Validation Loss: 0.173
# Epoch: 70:
# - Spend 6.01 seconds on training process
# - Spend 5.18 seconds on validation process
# - Training Loss: 0.002, Validation Loss: 0.245
# Epoch: 71:
# - Spend 6.01 seconds on training process
# - Spend 5.75 seconds on validation process
# - Training Loss: 0.004, Validation Loss: 0.362
# Epoch: 72:
# - Spend 6.01 seconds on training process
# - Spend 5.00 seconds on validation process
# - Training Loss: 0.002, Validation Loss: 0.107
# Epoch: 73:
# - Spend 5.90 seconds on training process
# - Spend 5.01 seconds on validation process
# - Training Loss: 0.002, Validation Loss: 0.126
# Epoch: 74:
# - Spend 5.94 seconds on training process
# - Spend 5.09 seconds on validation process
# - Training Loss: 0.002, Validation Loss: 0.106
# Epoch: 75:
# - Spend 5.93 seconds on training process
# - Spend 5.06 seconds on validation process
# - Training Loss: 0.004, Validation Loss: 0.124
# Epoch: 76:
# - Spend 5.97 seconds on training process
# - Spend 5.03 seconds on validation process
# - Training Loss: 0.001, Validation Loss: 0.018
# Epoch: 77:
# - Spend 5.94 seconds on training process
# - Spend 5.05 seconds on validation process
# - Training Loss: 0.001, Validation Loss: 0.348
# Epoch: 78:
# - Spend 5.92 seconds on training process
# - Spend 5.04 seconds on validation process
# - Training Loss: 0.003, Validation Loss: 0.546
# Epoch: 79:
# - Spend 6.00 seconds on training process
# - Spend 5.02 seconds on validation process
# - Training Loss: 0.004, Validation Loss: 0.136
# Epoch: 80:
# - Spend 5.90 seconds on training process
# - Spend 4.97 seconds on validation process
# - Training Loss: 0.002, Validation Loss: 0.156
# Epoch: 81:
# - Spend 5.91 seconds on training process
# - Spend 5.00 seconds on validation process
# - Training Loss: 0.002, Validation Loss: 0.192
# Epoch: 82:
# - Spend 5.93 seconds on training process
# - Spend 5.66 seconds on validation process
# - Training Loss: 0.002, Validation Loss: 0.008
# Epoch: 83:
# - Spend 5.91 seconds on training process
# - Spend 4.99 seconds on validation process
# - Training Loss: 0.000, Validation Loss: 0.161
# Epoch: 84:
# - Spend 5.94 seconds on training process
# - Spend 5.06 seconds on validation process
# - Training Loss: 0.005, Validation Loss: 0.191
# Epoch: 85:
# - Spend 5.99 seconds on training process
# - Spend 5.03 seconds on validation process
# - Training Loss: 0.003, Validation Loss: 0.368
# Epoch: 86:
# - Spend 5.90 seconds on training process
# - Spend 5.04 seconds on validation process
# - Training Loss: 0.001, Validation Loss: 0.032
# Epoch: 87:
# - Spend 5.96 seconds on training process
# - Spend 5.00 seconds on validation process
# - Training Loss: 0.001, Validation Loss: 0.665
# Epoch: 88:
# - Spend 5.95 seconds on training process
# - Spend 5.02 seconds on validation process
# - Training Loss: 0.003, Validation Loss: 0.084
# Epoch: 89:
# - Spend 5.84 seconds on training process
# - Spend 5.00 seconds on validation process
# - Training Loss: 0.004, Validation Loss: 0.436
# Epoch: 90:
# - Spend 5.91 seconds on training process
# - Spend 4.97 seconds on validation process
# - Training Loss: 0.002, Validation Loss: 0.465
# Epoch: 91:
# - Spend 5.92 seconds on training process
# - Spend 4.99 seconds on validation process
# - Training Loss: 0.002, Validation Loss: 0.069
# Epoch: 92:
# - Spend 5.91 seconds on training process
# - Spend 5.10 seconds on validation process
# - Training Loss: 0.001, Validation Loss: 0.095
# Epoch: 93:
# - Spend 6.52 seconds on training process
# - Spend 5.08 seconds on validation process
# - Training Loss: 0.002, Validation Loss: 0.151
# Epoch: 94:
# - Spend 5.95 seconds on training process
# - Spend 5.03 seconds on validation process
# - Training Loss: 0.003, Validation Loss: 0.099
# Epoch: 95:
# - Spend 5.90 seconds on training process
# - Spend 5.03 seconds on validation process
# - Training Loss: 0.003, Validation Loss: 0.153
# Epoch: 96:
# - Spend 5.87 seconds on training process
# - Spend 5.02 seconds on validation process
# - Training Loss: 0.001, Validation Loss: 0.012
# Epoch: 97:
# - Spend 5.87 seconds on training process
# - Spend 5.01 seconds on validation process
# - Training Loss: 0.002, Validation Loss: 0.081
# Epoch: 98:
# - Spend 5.92 seconds on training process
# - Spend 4.99 seconds on validation process
# - Training Loss: 0.003, Validation Loss: 0.171
# Epoch: 99:
# - Spend 5.89 seconds on training process
# - Spend 4.98 seconds on validation process
# - Training Loss: 0.001, Validation Loss: 0.390
# Spend 1169 seconds on entire training process

# %% [markdown]
# ## Training & Validation Process (w/ Early Stopping)

# %%
model = ANN(
    input_size=input_size,
    hidden_size=hidden_size,
    num_class=num_class 
)
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_function = nn.CrossEntropyLoss()

# %%
init_start = time.time()

# init min validation loss
min_valid_loss = 100
patience = 5
trap_count = 0

for epoch in range(0, 100):
    print(f'Epoch: {epoch}:')
    train_start_time = time.time()
    train_loss = train(model, train_loader, optimizer, loss_function, epoch)

    valid_start_time = time.time()
    val_loss = valid(model, valid_loader, loss_function)
    
    # Early Stopping
    if val_loss < min_valid_loss:
        min_valid_loss = val_loss
        trap_count = 0
    else:
        trap_count += 1
    if trap_count >= patience:
        print(f'Validation loss not decrease ...{trap_count} times... stop training....')
        # save model weight
        torch.save(model.state_dict(), 'best_model.pkl')
        break

    print('- Training Loss: %.3f, Validation Loss: %.3f [%s/%s]' % (train_loss, val_loss, trap_count, patience))


print('Spend %3.f seconds on entire training process' % (time.time() - init_start))
# Out:
# Epoch: 0:
# - Training Loss: 0.265, Validation Loss: 11.252 [0/5]
# Epoch: 1:
# - Training Loss: 0.102, Validation Loss: 6.490 [0/5]
# Epoch: 2:
# - Training Loss: 0.066, Validation Loss: 5.028 [0/5]
# Epoch: 3:
# - Training Loss: 0.047, Validation Loss: 3.039 [0/5]
# Epoch: 4:
# - Training Loss: 0.033, Validation Loss: 2.634 [0/5]
# Epoch: 5:
# - Training Loss: 0.026, Validation Loss: 2.246 [0/5]
# Epoch: 6:
# - Training Loss: 0.020, Validation Loss: 1.269 [0/5]
# Epoch: 7:
# - Training Loss: 0.016, Validation Loss: 1.082 [0/5]
# Epoch: 8:
# - Training Loss: 0.012, Validation Loss: 0.868 [0/5]
# Epoch: 9:
# - Training Loss: 0.008, Validation Loss: 0.758 [0/5]
# Epoch: 10:
# - Training Loss: 0.008, Validation Loss: 0.803 [1/5]
# Epoch: 11:
# - Training Loss: 0.008, Validation Loss: 0.857 [2/5]
# Epoch: 12:
# - Training Loss: 0.008, Validation Loss: 0.946 [3/5]
# Epoch: 13:
# - Training Loss: 0.008, Validation Loss: 0.626 [0/5]
# Epoch: 14:
# - Training Loss: 0.006, Validation Loss: 0.271 [0/5]
# Epoch: 15:
# - Training Loss: 0.005, Validation Loss: 0.232 [0/5]
# Epoch: 16:
# - Training Loss: 0.004, Validation Loss: 0.443 [1/5]
# Epoch: 17:
# - Training Loss: 0.004, Validation Loss: 0.465 [2/5]
# Epoch: 18:
# - Training Loss: 0.004, Validation Loss: 0.954 [3/5]
# Epoch: 19:
# - Training Loss: 0.005, Validation Loss: 0.136 [0/5]
# Epoch: 20:
# - Training Loss: 0.004, Validation Loss: 0.963 [1/5]
# Epoch: 21:
# - Training Loss: 0.005, Validation Loss: 0.116 [0/5]
# Epoch: 22:
# - Training Loss: 0.001, Validation Loss: 0.013 [0/5]
# Epoch: 23:
# - Training Loss: 0.000, Validation Loss: 0.007 [0/5]
# Epoch: 24:
# - Training Loss: 0.000, Validation Loss: 0.004 [0/5]
# Epoch: 25:
# - Training Loss: 0.000, Validation Loss: 0.004 [1/5]
# Epoch: 26:
# - Training Loss: 0.000, Validation Loss: 0.003 [0/5]
# Epoch: 27:
# - Training Loss: 0.015, Validation Loss: 0.484 [1/5]
# Epoch: 28:
# - Training Loss: 0.003, Validation Loss: 0.081 [2/5]
# Epoch: 29:
# - Training Loss: 0.001, Validation Loss: 0.251 [3/5]
# Epoch: 30:
# - Training Loss: 0.006, Validation Loss: 0.119 [4/5]
# Epoch: 31:
# Validation loss not decrease ...5 times... stop training....
# Spend 373 seconds on entire training process
