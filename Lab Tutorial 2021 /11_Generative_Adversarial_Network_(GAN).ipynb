# %% [markdown]
# ## Import

# %%
import torch
import torch.nn as nn

from torchvision.datasets import MNIST
from torchvision.utils import save_image
import torchvision.transforms as transforms

from torch.autograd import Variable
from torch.utils.data import DataLoader

# %% [markdown]
# ## Dataset & DataLoader

# %% [markdown]
# ### Transforms

# %%
transform = transforms.Compose([
     transforms.ToTensor(),
     transforms.Normalize(mean=0.5, std=0.5)
])

# %%
def denorm(x):
  # 平均0.5 三個標準差 為 -1, 2
  out = (x+1)/2
  return out.clamp(0, 1)

# %% [markdown]
# ### Dataset - MNIST

# %%
train_dataset = MNIST(root = './', train=True, download=True, transform=transform)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ./MNIST/raw/train-images-idx3-ubyte.gz to ./MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ./MNIST/raw/train-labels-idx1-ubyte.gz to ./MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./MNIST/raw/t10k-images-idx3-ubyte.gz to ./MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ./MNIST/raw/t10k-labels-idx1-ubyte.gz to ./MNIST/raw
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/mnist.py:498: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:180.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %% [markdown]
# ### DataLoader

# %%
data_loader = DataLoader(
        dataset = train_dataset, 
        batch_size = 64, 
        shuffle = False
)

# %% [markdown]
# ## Models
#
# * Discriminator
# * Generator

# %% [markdown]
# ### Discriminator

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.discriminator = nn.Sequential(
            nn.Linear(28*28, 256),
            nn.LeakyReLU(0.2),
            nn.Linear(256, 1),
            nn.Sigmoid()
        )
    def forward(self, x):
        return self.discriminator(x)

# %% [markdown]
# ### Generator

# %%
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.generator = nn.Sequential(
            nn.Linear(64, 1024),
            nn.ReLU(),
            nn.Linear(1024, 1024),
            nn.ReLU(),
            nn.Linear(1024, 784),
            nn.Tanh()
        )
    def forward(self, x):
        return self.generator(x)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

discriminator = Discriminator().to(device)
generator = Generator().to(device)

# %% [markdown]
# ## Loss Function & Optimizer

# %%
# loss function
loss_func = nn.BCELoss()

# optimizer
d_opt = torch.optim.Adam(discriminator.parameters(), lr=0.0001)
g_opt = torch.optim.Adam(generator.parameters(), lr=0.0001)

# %% [markdown]
# ## Training Model

# %%
for epoch in range(300):
    for idx, (images, _) in enumerate(data_loader):

        batch_size = images.size(0)
        real_images = Variable(images.view(batch_size, -1)).to(device)
    
        # feed real images to discriminator
        real_outputs = discriminator(real_images)
        real_labels = torch.ones(batch_size, 1).to(device)
        
        # generate fake images 
        noise = (torch.rand(batch_size, 64)).to(device)
        fake_images = generator(noise)
        # feed fake images to discriminator
        fake_outputs = discriminator(fake_images)
        fake_labels = torch.zeros(batch_size, 1).to(device)

        outputs = torch.cat((real_outputs, fake_outputs), 0)
        targets = torch.cat((real_labels, fake_labels), 0)

        # Zero the parameter gradients
        # Backward propagation
        d_opt.zero_grad()
        d_loss = loss_func(outputs, targets)
        d_loss.backward()
        d_opt.step()

        # generate fake images
        noise = (torch.rand(batch_size, 64)).to(device)
        fake_images = generator(noise)
        fake_outputs = discriminator(fake_images)
        targets = torch.ones(batch_size, 1).to(device)
        g_loss = loss_func(fake_outputs, targets)
        g_opt.zero_grad()
        g_loss.backward()
        g_opt.step()

        if (idx+1)%300 == 0:
            print('Epoch %d, batch %d, d_loss %.4f g_loss %.4f'
            %(epoch, idx+1, d_loss.data, g_loss.data))
        
        if epoch == 0:
            images = images.view(images.size(0), 1, 28, 28)
            save_image(denorm(images), './data/real_images.png')
        
    # save fake image
    fake_images = fake_images.view(fake_images.size(0), 1, 28, 28) # c, w, h
    save_image(denorm(fake_images), './data/fake_images-%d.png'%(epoch+1))
# Out:
# Epoch 0, batch 300, d_loss 0.1410 g_loss 1.9030
# Epoch 0, batch 600, d_loss 0.5441 g_loss 0.6985
# Epoch 0, batch 900, d_loss 0.4907 g_loss 0.7557
# Epoch 1, batch 300, d_loss 0.5835 g_loss 0.7393
# Epoch 1, batch 600, d_loss 0.6794 g_loss 0.6926
# Epoch 1, batch 900, d_loss 0.6712 g_loss 0.7256
# Epoch 2, batch 300, d_loss 0.7098 g_loss 0.7280
# Epoch 2, batch 600, d_loss 0.5228 g_loss 0.8896
# Epoch 2, batch 900, d_loss 0.5813 g_loss 0.8695
# Epoch 3, batch 300, d_loss 0.7585 g_loss 0.6395
# Epoch 3, batch 600, d_loss 0.5865 g_loss 0.7970
# Epoch 3, batch 900, d_loss 0.6527 g_loss 0.7741
# Epoch 4, batch 300, d_loss 0.4932 g_loss 0.9478
# Epoch 4, batch 600, d_loss 0.5905 g_loss 0.8568
# Epoch 4, batch 900, d_loss 0.4868 g_loss 0.9856
# Epoch 5, batch 300, d_loss 0.4224 g_loss 1.0539
# Epoch 5, batch 600, d_loss 0.5538 g_loss 0.7413
# Epoch 5, batch 900, d_loss 0.4540 g_loss 1.0465
# Epoch 6, batch 300, d_loss 0.8604 g_loss 0.4979
# Epoch 6, batch 600, d_loss 0.6576 g_loss 0.7903
# Epoch 6, batch 900, d_loss 0.7907 g_loss 0.5785
# Epoch 7, batch 300, d_loss 0.6409 g_loss 0.8428
# Epoch 7, batch 600, d_loss 0.6337 g_loss 0.8248
# Epoch 7, batch 900, d_loss 0.4556 g_loss 0.9622
# Epoch 8, batch 300, d_loss 0.6260 g_loss 0.7703
# Epoch 8, batch 600, d_loss 0.4290 g_loss 1.1653
# Epoch 8, batch 900, d_loss 0.5316 g_loss 0.8907
# Epoch 9, batch 300, d_loss 0.7461 g_loss 0.6558
# Epoch 9, batch 600, d_loss 0.5981 g_loss 0.8607
# Epoch 9, batch 900, d_loss 0.7004 g_loss 0.7916
# Epoch 10, batch 300, d_loss 0.7019 g_loss 0.7413
# Epoch 10, batch 600, d_loss 0.5278 g_loss 1.0257
# Epoch 10, batch 900, d_loss 0.4856 g_loss 1.0101
# Epoch 11, batch 300, d_loss 0.3962 g_loss 1.2020
# Epoch 11, batch 600, d_loss 0.6086 g_loss 0.9802
# Epoch 11, batch 900, d_loss 0.6106 g_loss 0.9358
# Epoch 12, batch 300, d_loss 0.7668 g_loss 0.6832
# Epoch 12, batch 600, d_loss 0.7377 g_loss 0.6678
# Epoch 12, batch 900, d_loss 1.1456 g_loss 0.4497
# Epoch 13, batch 300, d_loss 0.5270 g_loss 1.0814
# Epoch 13, batch 600, d_loss 0.2911 g_loss 1.6674
# Epoch 13, batch 900, d_loss 0.0575 g_loss 2.9227
# Epoch 14, batch 300, d_loss 0.0921 g_loss 2.7506
# Epoch 14, batch 600, d_loss 0.1748 g_loss 2.2338
# Epoch 14, batch 900, d_loss 0.0550 g_loss 3.0572
# Epoch 15, batch 300, d_loss 0.0138 g_loss 4.0532
# Epoch 15, batch 600, d_loss 0.0036 g_loss 5.2242
# Epoch 15, batch 900, d_loss 0.0446 g_loss 3.0795
# Epoch 16, batch 300, d_loss 0.0255 g_loss 3.9053
# Epoch 16, batch 600, d_loss 0.0085 g_loss 5.1420
# Epoch 16, batch 900, d_loss 0.0045 g_loss 5.7531
# Epoch 17, batch 300, d_loss 0.0015 g_loss 6.1998
# Epoch 17, batch 600, d_loss 0.0007 g_loss 6.7774
# Epoch 17, batch 900, d_loss 0.0009 g_loss 6.6703
# Epoch 18, batch 300, d_loss 0.0067 g_loss 4.9495
# Epoch 18, batch 600, d_loss 0.0026 g_loss 6.1496
# Epoch 18, batch 900, d_loss 0.0015 g_loss 6.5943
# Epoch 19, batch 300, d_loss 0.0036 g_loss 5.8472
# Epoch 19, batch 600, d_loss 0.0039 g_loss 6.2346
# Epoch 19, batch 900, d_loss 0.0025 g_loss 6.4003
# Epoch 20, batch 300, d_loss 0.0003 g_loss 7.9749
# Epoch 20, batch 600, d_loss 0.0002 g_loss 8.9835
# Epoch 20, batch 900, d_loss 0.0001 g_loss 9.1639
# Epoch 21, batch 300, d_loss 0.0001 g_loss 9.7747
# Epoch 21, batch 600, d_loss 0.0000 g_loss 9.9479
# Epoch 21, batch 900, d_loss 0.0000 g_loss 10.3162
# Epoch 22, batch 300, d_loss 0.0000 g_loss 10.1255
# Epoch 22, batch 600, d_loss 0.0001 g_loss 9.2633
# Epoch 22, batch 900, d_loss 0.0004 g_loss 7.7431
# Epoch 23, batch 300, d_loss 0.0003 g_loss 7.6359
# Epoch 23, batch 600, d_loss 0.0004 g_loss 7.7179
# Epoch 23, batch 900, d_loss 0.0002 g_loss 8.7551
# Epoch 24, batch 300, d_loss 0.0002 g_loss 8.8486
# Epoch 24, batch 600, d_loss 0.0001 g_loss 9.7244
# Epoch 24, batch 900, d_loss 0.0000 g_loss 10.1703
# Epoch 25, batch 300, d_loss 0.0001 g_loss 9.8397
# Epoch 25, batch 600, d_loss 0.0000 g_loss 10.6273
# Epoch 25, batch 900, d_loss 0.0000 g_loss 9.5939
# Epoch 26, batch 300, d_loss 0.0000 g_loss 10.2370
# Epoch 26, batch 600, d_loss 0.0000 g_loss 11.2116
# Epoch 26, batch 900, d_loss 0.0000 g_loss 11.0737
# Epoch 27, batch 300, d_loss 0.0000 g_loss 12.1370
# Epoch 27, batch 600, d_loss 0.0000 g_loss 12.1776
# Epoch 27, batch 900, d_loss 0.0000 g_loss 12.5507
# Epoch 28, batch 300, d_loss 0.0000 g_loss 12.8844
# Epoch 28, batch 600, d_loss 0.0000 g_loss 13.0636
# Epoch 28, batch 900, d_loss 0.0000 g_loss 9.8653
# Epoch 29, batch 300, d_loss 0.0001 g_loss 8.7859
# Epoch 29, batch 600, d_loss 0.0000 g_loss 9.6969
# Epoch 29, batch 900, d_loss 0.0000 g_loss 10.5919
# Epoch 30, batch 300, d_loss 0.0000 g_loss 11.1656
# Epoch 30, batch 600, d_loss 0.0000 g_loss 9.7019
# Epoch 30, batch 900, d_loss 0.0000 g_loss 11.4608
# Epoch 31, batch 300, d_loss 0.0000 g_loss 12.1211
# Epoch 31, batch 600, d_loss 0.0000 g_loss 12.2906
# Epoch 31, batch 900, d_loss 0.0000 g_loss 12.9207
# Epoch 32, batch 300, d_loss 0.0000 g_loss 13.2698
# Epoch 32, batch 600, d_loss 0.0000 g_loss 13.5274
# Epoch 32, batch 900, d_loss 0.0000 g_loss 13.7796
# Epoch 33, batch 300, d_loss 0.0000 g_loss 14.0954
# Epoch 33, batch 600, d_loss 0.0000 g_loss 14.3112
# Epoch 33, batch 900, d_loss 0.0000 g_loss 14.4337
# Epoch 34, batch 300, d_loss 0.0000 g_loss 11.6871
# Epoch 34, batch 600, d_loss 0.0000 g_loss 12.6363
# Epoch 34, batch 900, d_loss 0.0000 g_loss 14.2752
# Epoch 35, batch 300, d_loss 0.0000 g_loss 14.5636
# Epoch 35, batch 600, d_loss 0.0000 g_loss 14.1440
# Epoch 35, batch 900, d_loss 0.0000 g_loss 14.0829
# Epoch 36, batch 300, d_loss 0.0000 g_loss 14.7350
# Epoch 36, batch 600, d_loss 0.0000 g_loss 15.2890
# Epoch 36, batch 900, d_loss 0.0000 g_loss 15.8903
# Epoch 37, batch 300, d_loss 0.0000 g_loss 15.9788
# Epoch 37, batch 600, d_loss 0.0000 g_loss 16.4145
# Epoch 37, batch 900, d_loss 0.0000 g_loss 16.6085
# Epoch 38, batch 300, d_loss 0.0000 g_loss 16.7948
# Epoch 38, batch 600, d_loss 0.0000 g_loss 16.8307
# Epoch 38, batch 900, d_loss 0.0000 g_loss 17.2688
# Epoch 39, batch 300, d_loss 0.0000 g_loss 17.3381
# Epoch 39, batch 600, d_loss 0.0000 g_loss 17.6672
# Epoch 39, batch 900, d_loss 0.0000 g_loss 17.7784
# Epoch 40, batch 300, d_loss 0.0005 g_loss 9.6704
# Epoch 40, batch 600, d_loss 0.0000 g_loss 11.2133
# Epoch 40, batch 900, d_loss 0.0000 g_loss 11.1884
# Epoch 41, batch 300, d_loss 0.0000 g_loss 12.4690
# Epoch 41, batch 600, d_loss 0.0000 g_loss 12.6462
# Epoch 41, batch 900, d_loss 0.0000 g_loss 13.1691
# Epoch 42, batch 300, d_loss 0.0000 g_loss 13.4951
# Epoch 42, batch 600, d_loss 0.0000 g_loss 13.7467
# Epoch 42, batch 900, d_loss 0.0000 g_loss 13.8069
# Epoch 43, batch 300, d_loss 0.0000 g_loss 14.1270
# Epoch 43, batch 600, d_loss 0.0000 g_loss 14.2722
# Epoch 43, batch 900, d_loss 0.0000 g_loss 14.3341
# Epoch 44, batch 300, d_loss 0.0000 g_loss 14.5747
# Epoch 44, batch 600, d_loss 0.0000 g_loss 14.7498
# Epoch 44, batch 900, d_loss 0.0000 g_loss 14.9934
# Epoch 45, batch 300, d_loss 0.0000 g_loss 15.0332
# Epoch 45, batch 600, d_loss 0.0000 g_loss 15.3825
# Epoch 45, batch 900, d_loss 0.0000 g_loss 15.5788
# Epoch 46, batch 300, d_loss 0.0000 g_loss 15.7603
# Epoch 46, batch 600, d_loss 0.0000 g_loss 15.0601
# Epoch 46, batch 900, d_loss 0.0000 g_loss 15.3832
# Epoch 47, batch 300, d_loss 0.0000 g_loss 15.7578
# Epoch 47, batch 600, d_loss 0.0000 g_loss 16.0786
# Epoch 47, batch 900, d_loss 0.0000 g_loss 16.1116
# Epoch 48, batch 300, d_loss 0.0000 g_loss 16.3187
# Epoch 48, batch 600, d_loss 0.0000 g_loss 16.7089
# Epoch 48, batch 900, d_loss 0.0000 g_loss 16.8022
# Epoch 49, batch 300, d_loss 0.0000 g_loss 17.0581
# Epoch 49, batch 600, d_loss 0.0000 g_loss 17.0680
# Epoch 49, batch 900, d_loss 0.0000 g_loss 17.3885
# Epoch 50, batch 300, d_loss 0.0000 g_loss 17.6313
# Epoch 50, batch 600, d_loss 0.0000 g_loss 17.5528
# Epoch 50, batch 900, d_loss 0.0000 g_loss 17.9486
# Epoch 51, batch 300, d_loss 0.0000 g_loss 18.1195
# Epoch 51, batch 600, d_loss 0.0000 g_loss 18.3063
# Epoch 51, batch 900, d_loss 0.0000 g_loss 18.1004
# Epoch 52, batch 300, d_loss 0.0000 g_loss 18.6240
# Epoch 52, batch 600, d_loss 0.0000 g_loss 18.8082
# Epoch 52, batch 900, d_loss 0.0000 g_loss 17.9359
# Epoch 53, batch 300, d_loss 0.0000 g_loss 12.3482
# Epoch 53, batch 600, d_loss 0.0000 g_loss 13.1052
# Epoch 53, batch 900, d_loss 0.0000 g_loss 13.2307
# Epoch 54, batch 300, d_loss 0.0000 g_loss 13.3727
# Epoch 54, batch 600, d_loss 0.0000 g_loss 13.7597
# Epoch 54, batch 900, d_loss 0.0000 g_loss 13.9353
# Epoch 55, batch 300, d_loss 0.0000 g_loss 14.1091
# Epoch 55, batch 600, d_loss 0.0000 g_loss 14.1985
# Epoch 55, batch 900, d_loss 0.0000 g_loss 14.3741
# Epoch 56, batch 300, d_loss 0.0000 g_loss 14.6119
# Epoch 56, batch 600, d_loss 0.0000 g_loss 14.7882
# Epoch 56, batch 900, d_loss 0.0000 g_loss 14.8529
# Epoch 57, batch 300, d_loss 0.0000 g_loss 14.9894
# Epoch 57, batch 600, d_loss 0.0000 g_loss 15.1080
# Epoch 57, batch 900, d_loss 0.0000 g_loss 15.3709
# Epoch 58, batch 300, d_loss 0.0000 g_loss 15.5360
# Epoch 58, batch 600, d_loss 0.0000 g_loss 15.6681
# Epoch 58, batch 900, d_loss 0.0000 g_loss 15.7296
# Epoch 59, batch 300, d_loss 0.0000 g_loss 15.9121
# Epoch 59, batch 600, d_loss 0.0000 g_loss 16.2021
# Epoch 59, batch 900, d_loss 0.0000 g_loss 16.4038
# Epoch 60, batch 300, d_loss 0.0000 g_loss 16.5326
# Epoch 60, batch 600, d_loss 0.0000 g_loss 16.6963
# Epoch 60, batch 900, d_loss 0.0000 g_loss 16.8698
# Epoch 61, batch 300, d_loss 0.0000 g_loss 16.9923
# Epoch 61, batch 600, d_loss 0.0000 g_loss 17.2270
# Epoch 61, batch 900, d_loss 0.0000 g_loss 17.2572
# Epoch 62, batch 300, d_loss 0.0000 g_loss 17.4961
# Epoch 62, batch 600, d_loss 0.0000 g_loss 17.6121
# Epoch 62, batch 900, d_loss 0.0000 g_loss 17.8165
# Epoch 63, batch 300, d_loss 0.0000 g_loss 17.9401
# Epoch 63, batch 600, d_loss 0.0000 g_loss 18.1088
# Epoch 63, batch 900, d_loss 0.0000 g_loss 18.3796
# Epoch 64, batch 300, d_loss 0.0000 g_loss 18.4641
# Epoch 64, batch 600, d_loss 0.0000 g_loss 18.6173
# Epoch 64, batch 900, d_loss 0.0000 g_loss 18.6947
# Epoch 65, batch 300, d_loss 0.0000 g_loss 14.8101
# Epoch 65, batch 600, d_loss 0.0000 g_loss 16.5219
# Epoch 65, batch 900, d_loss 0.0000 g_loss 17.1601
# Epoch 66, batch 300, d_loss 0.0000 g_loss 17.9993
# Epoch 66, batch 600, d_loss 0.0000 g_loss 18.2850
# Epoch 66, batch 900, d_loss 0.0000 g_loss 18.5727
# Epoch 67, batch 300, d_loss 0.0000 g_loss 18.4403
# Epoch 67, batch 600, d_loss 0.0000 g_loss 19.0533
# Epoch 67, batch 900, d_loss 0.0000 g_loss 19.0112
# Epoch 68, batch 300, d_loss 0.0000 g_loss 19.2751
# Epoch 68, batch 600, d_loss 0.0000 g_loss 19.0751
# Epoch 68, batch 900, d_loss 0.0000 g_loss 19.5175
# Epoch 69, batch 300, d_loss 0.0000 g_loss 19.5396
# Epoch 69, batch 600, d_loss 0.0000 g_loss 19.8025
# Epoch 69, batch 900, d_loss 0.0000 g_loss 17.2784
# Epoch 70, batch 300, d_loss 0.0000 g_loss 18.8335
# Epoch 70, batch 600, d_loss 0.0000 g_loss 13.6589
# Epoch 70, batch 900, d_loss 0.0000 g_loss 11.1316
# Epoch 71, batch 300, d_loss 0.0000 g_loss 11.9478
# Epoch 71, batch 600, d_loss 0.0000 g_loss 12.7248
# Epoch 71, batch 900, d_loss 0.0000 g_loss 13.4094
# Epoch 72, batch 300, d_loss 0.0000 g_loss 13.7627
# Epoch 72, batch 600, d_loss 0.0000 g_loss 14.1740
# Epoch 72, batch 900, d_loss 0.0000 g_loss 14.2237
# Epoch 73, batch 300, d_loss 0.0000 g_loss 14.5779
# Epoch 73, batch 600, d_loss 0.0000 g_loss 14.8223
# Epoch 73, batch 900, d_loss 0.0000 g_loss 15.0008
# Epoch 74, batch 300, d_loss 0.0000 g_loss 15.2679
# Epoch 74, batch 600, d_loss 0.0000 g_loss 15.1731
# Epoch 74, batch 900, d_loss 0.0000 g_loss 15.5455
# Epoch 75, batch 300, d_loss 0.0000 g_loss 15.8114
# Epoch 75, batch 600, d_loss 0.0000 g_loss 16.0293
# Epoch 75, batch 900, d_loss 0.0000 g_loss 15.7850
# Epoch 76, batch 300, d_loss 0.0000 g_loss 16.2662
# Epoch 76, batch 600, d_loss 0.0000 g_loss 15.9732
# Epoch 76, batch 900, d_loss 0.0000 g_loss 16.3416
# Epoch 77, batch 300, d_loss 0.0000 g_loss 16.7526
# Epoch 77, batch 600, d_loss 0.0000 g_loss 16.8525
# Epoch 77, batch 900, d_loss 0.0000 g_loss 16.9530
# Epoch 78, batch 300, d_loss 0.0000 g_loss 11.2625
# Epoch 78, batch 600, d_loss 0.0000 g_loss 10.5735
# Epoch 78, batch 900, d_loss 0.0000 g_loss 13.2747
# Epoch 79, batch 300, d_loss 0.0000 g_loss 13.7138
# Epoch 79, batch 600, d_loss 0.0000 g_loss 12.3532
# Epoch 79, batch 900, d_loss 0.0000 g_loss 13.5805
# Epoch 80, batch 300, d_loss 0.0000 g_loss 12.0268
# Epoch 80, batch 600, d_loss 0.0000 g_loss 13.6524
# Epoch 80, batch 900, d_loss 0.0000 g_loss 13.8377
# Epoch 81, batch 300, d_loss 0.0000 g_loss 14.4012
# Epoch 81, batch 600, d_loss 0.0000 g_loss 14.1586
# Epoch 81, batch 900, d_loss 0.0000 g_loss 14.9257
# Epoch 82, batch 300, d_loss 0.0000 g_loss 14.8730
# Epoch 82, batch 600, d_loss 0.0000 g_loss 13.8879
# Epoch 82, batch 900, d_loss 0.0000 g_loss 15.4052
# Epoch 83, batch 300, d_loss 0.0000 g_loss 15.4730
# Epoch 83, batch 600, d_loss 0.0000 g_loss 16.0641
# Epoch 83, batch 900, d_loss 0.0000 g_loss 16.2790
# Epoch 84, batch 300, d_loss 0.0000 g_loss 16.1171
# Epoch 84, batch 600, d_loss 0.0000 g_loss 16.7770
# Epoch 84, batch 900, d_loss 0.0000 g_loss 16.7952
# Epoch 85, batch 300, d_loss 0.0000 g_loss 16.8536
# Epoch 85, batch 600, d_loss 0.0000 g_loss 16.0779
# Epoch 85, batch 900, d_loss 0.0000 g_loss 14.5117
# Epoch 86, batch 300, d_loss 0.0000 g_loss 15.8069
# Epoch 86, batch 600, d_loss 0.0000 g_loss 15.8587
# Epoch 86, batch 900, d_loss 0.0000 g_loss 16.5004
# Epoch 87, batch 300, d_loss 0.0000 g_loss 16.5299
# Epoch 87, batch 600, d_loss 0.0000 g_loss 17.3281
# Epoch 87, batch 900, d_loss 0.0000 g_loss 17.1922
# Epoch 88, batch 300, d_loss 0.0000 g_loss 17.2634
# Epoch 88, batch 600, d_loss 0.0000 g_loss 17.5764
# Epoch 88, batch 900, d_loss 0.0000 g_loss 12.8068
# Epoch 89, batch 300, d_loss 0.0000 g_loss 13.3146
# Epoch 89, batch 600, d_loss 0.0000 g_loss 14.4412
# Epoch 89, batch 900, d_loss 0.0000 g_loss 14.9673
# Epoch 90, batch 300, d_loss 0.0000 g_loss 15.1537
# Epoch 90, batch 600, d_loss 0.0000 g_loss 15.2714
# Epoch 90, batch 900, d_loss 0.0000 g_loss 15.4771
# Epoch 91, batch 300, d_loss 0.0000 g_loss 14.5954
# Epoch 91, batch 600, d_loss 0.0000 g_loss 14.2489
# Epoch 91, batch 900, d_loss 0.0000 g_loss 15.0206
# Epoch 92, batch 300, d_loss 0.0000 g_loss 15.1806
# Epoch 92, batch 600, d_loss 0.0000 g_loss 15.6789
# Epoch 92, batch 900, d_loss 0.0000 g_loss 16.1981
# Epoch 93, batch 300, d_loss 0.0000 g_loss 16.2741
# Epoch 93, batch 600, d_loss 0.0000 g_loss 16.3970
# Epoch 93, batch 900, d_loss 0.0000 g_loss 16.6500
# Epoch 94, batch 300, d_loss 0.0000 g_loss 16.9639
# Epoch 94, batch 600, d_loss 0.0000 g_loss 17.2287
# Epoch 94, batch 900, d_loss 0.0000 g_loss 17.2311
# Epoch 95, batch 300, d_loss 0.0000 g_loss 17.2105
# Epoch 95, batch 600, d_loss 0.0000 g_loss 17.4340
# Epoch 95, batch 900, d_loss 0.0000 g_loss 17.8477
# Epoch 96, batch 300, d_loss 0.0000 g_loss 13.8910
# Epoch 96, batch 600, d_loss 0.0000 g_loss 16.8617
# Epoch 96, batch 900, d_loss 0.0000 g_loss 16.9386
# Epoch 97, batch 300, d_loss 0.0000 g_loss 17.9620
# Epoch 97, batch 600, d_loss 0.0000 g_loss 18.0528
# Epoch 97, batch 900, d_loss 0.0000 g_loss 18.4018
# Epoch 98, batch 300, d_loss 0.0000 g_loss 18.6545
# Epoch 98, batch 600, d_loss 0.0000 g_loss 18.7328
# Epoch 98, batch 900, d_loss 0.0000 g_loss 19.0141
# Epoch 99, batch 300, d_loss 0.0000 g_loss 19.1322
# Epoch 99, batch 600, d_loss 0.0000 g_loss 19.6584
# Epoch 99, batch 900, d_loss 0.0000 g_loss 19.5972
# Epoch 100, batch 300, d_loss 0.0000 g_loss 19.8479
# Epoch 100, batch 600, d_loss 0.0000 g_loss 19.9635
# Epoch 100, batch 900, d_loss 0.0000 g_loss 20.0975
# Epoch 101, batch 300, d_loss 0.0000 g_loss 20.3759
# Epoch 101, batch 600, d_loss 0.0000 g_loss 20.3090
# Epoch 101, batch 900, d_loss 0.0000 g_loss 20.5285
# Epoch 102, batch 300, d_loss 0.0000 g_loss 20.6316
# Epoch 102, batch 600, d_loss 0.0000 g_loss 20.7820
# Epoch 102, batch 900, d_loss 0.0000 g_loss 21.0729
# Epoch 103, batch 300, d_loss 0.0000 g_loss 21.3079
# Epoch 103, batch 600, d_loss 0.0000 g_loss 21.4206
# Epoch 103, batch 900, d_loss 0.0000 g_loss 21.4856
# Epoch 104, batch 300, d_loss 0.0000 g_loss 21.5782
# Epoch 104, batch 600, d_loss 0.0000 g_loss 21.5706
# Epoch 104, batch 900, d_loss 0.0000 g_loss 21.7214
# Epoch 105, batch 300, d_loss 0.0000 g_loss 21.9919
# Epoch 105, batch 600, d_loss 0.0000 g_loss 22.0620
# Epoch 105, batch 900, d_loss 0.0000 g_loss 22.1679
# Epoch 106, batch 300, d_loss 0.0000 g_loss 22.4423
# Epoch 106, batch 600, d_loss 0.0000 g_loss 22.4965
# Epoch 106, batch 900, d_loss 0.0000 g_loss 22.2268
# Epoch 107, batch 300, d_loss 0.0000 g_loss 22.5156
# Epoch 107, batch 600, d_loss 0.0000 g_loss 22.6929
# Epoch 107, batch 900, d_loss 0.0000 g_loss 22.7248
# Epoch 108, batch 300, d_loss 0.0000 g_loss 22.8406
# Epoch 108, batch 600, d_loss 0.0000 g_loss 22.9506
# Epoch 108, batch 900, d_loss 0.0000 g_loss 22.9973
# Epoch 109, batch 300, d_loss 0.0000 g_loss 23.1444
# Epoch 109, batch 600, d_loss 0.0000 g_loss 23.1345
# Epoch 109, batch 900, d_loss 0.0000 g_loss 23.1632
# Epoch 110, batch 300, d_loss 0.0000 g_loss 23.3265
# Epoch 110, batch 600, d_loss 0.0000 g_loss 23.3665
# Epoch 110, batch 900, d_loss 0.0000 g_loss 23.4989
# Epoch 111, batch 300, d_loss 0.0000 g_loss 23.5005
# Epoch 111, batch 600, d_loss 0.0000 g_loss 23.6031
# Epoch 111, batch 900, d_loss 0.0000 g_loss 23.7672
# Epoch 112, batch 300, d_loss 0.0000 g_loss 23.9235
# Epoch 112, batch 600, d_loss 0.0000 g_loss 23.9120
# Epoch 112, batch 900, d_loss 0.0000 g_loss 23.9046
# Epoch 113, batch 300, d_loss 0.0000 g_loss 23.7683
# Epoch 113, batch 600, d_loss 0.0000 g_loss 24.0468
# Epoch 113, batch 900, d_loss 0.0000 g_loss 24.0109
# Epoch 114, batch 300, d_loss 0.0000 g_loss 24.0281
# Epoch 114, batch 600, d_loss 0.0000 g_loss 24.1015
# Epoch 114, batch 900, d_loss 0.0000 g_loss 24.1300
# Epoch 115, batch 300, d_loss 0.0000 g_loss 24.2129
# Epoch 115, batch 600, d_loss 0.0000 g_loss 24.2129
# Epoch 115, batch 900, d_loss 0.0000 g_loss 24.2504
# Epoch 116, batch 300, d_loss 0.0000 g_loss 24.3929
# Epoch 116, batch 600, d_loss 0.0000 g_loss 22.8287
# Epoch 116, batch 900, d_loss 0.0000 g_loss 21.4529
# Epoch 117, batch 300, d_loss 0.0000 g_loss 22.0435
# Epoch 117, batch 600, d_loss 0.0000 g_loss 22.0423
# Epoch 117, batch 900, d_loss 0.0000 g_loss 22.0884
# Epoch 118, batch 300, d_loss 0.0000 g_loss 22.6031
# Epoch 118, batch 600, d_loss 0.0000 g_loss 22.7841
# Epoch 118, batch 900, d_loss 0.0000 g_loss 22.9544
# Epoch 119, batch 300, d_loss 0.0000 g_loss 23.2374
# Epoch 119, batch 600, d_loss 0.0000 g_loss 23.3956
# Epoch 119, batch 900, d_loss 0.0000 g_loss 23.0941
# Epoch 120, batch 300, d_loss 0.0000 g_loss 23.3635
# Epoch 120, batch 600, d_loss 0.0000 g_loss 23.5519
# Epoch 120, batch 900, d_loss 0.0000 g_loss 23.6590
# Epoch 121, batch 300, d_loss 0.0000 g_loss 23.7094
# Epoch 121, batch 600, d_loss 0.0000 g_loss 24.0133
# Epoch 121, batch 900, d_loss 0.0000 g_loss 23.9193
# Epoch 122, batch 300, d_loss 0.0000 g_loss 23.9037
# Epoch 122, batch 600, d_loss 0.0000 g_loss 24.1262
# Epoch 122, batch 900, d_loss 0.0000 g_loss 23.9108
# Epoch 123, batch 300, d_loss 0.0000 g_loss 24.0335
# Epoch 123, batch 600, d_loss 0.0000 g_loss 24.2630
# Epoch 123, batch 900, d_loss 0.0000 g_loss 24.1748
# Epoch 124, batch 300, d_loss 0.0000 g_loss 24.3627
# Epoch 124, batch 600, d_loss 0.0000 g_loss 24.3411
# Epoch 124, batch 900, d_loss 0.0000 g_loss 24.5561
# Epoch 125, batch 300, d_loss 0.0000 g_loss 24.5974
# Epoch 125, batch 600, d_loss 0.0000 g_loss 24.5725
# Epoch 125, batch 900, d_loss 0.0000 g_loss 24.6413
# Epoch 126, batch 300, d_loss 0.0000 g_loss 24.6253
# Epoch 126, batch 600, d_loss 0.0000 g_loss 24.6381
# Epoch 126, batch 900, d_loss 0.0000 g_loss 24.7545
# Epoch 127, batch 300, d_loss 0.0000 g_loss 24.8576
# Epoch 127, batch 600, d_loss 0.0000 g_loss 24.6595
# Epoch 127, batch 900, d_loss 0.0000 g_loss 24.8223
# Epoch 128, batch 300, d_loss 0.0000 g_loss 24.9477
# Epoch 128, batch 600, d_loss 0.0000 g_loss 24.9495
# Epoch 128, batch 900, d_loss 0.0000 g_loss 24.8403
# Epoch 129, batch 300, d_loss 0.0000 g_loss 24.8867
# Epoch 129, batch 600, d_loss 0.0000 g_loss 24.9161
# Epoch 129, batch 900, d_loss 0.0000 g_loss 24.8689
# Epoch 130, batch 300, d_loss 0.0000 g_loss 24.8619
# Epoch 130, batch 600, d_loss 0.0000 g_loss 24.8994
# Epoch 130, batch 900, d_loss 0.0000 g_loss 24.9545
# Epoch 131, batch 300, d_loss 0.0000 g_loss 24.6232
# Epoch 131, batch 600, d_loss 0.0000 g_loss 24.4957
# Epoch 131, batch 900, d_loss 0.0000 g_loss 24.5051
# Epoch 132, batch 300, d_loss 0.0000 g_loss 24.5055
# Epoch 132, batch 600, d_loss 0.0000 g_loss 24.6362
# Epoch 132, batch 900, d_loss 0.0000 g_loss 24.8465
# Epoch 133, batch 300, d_loss 0.0000 g_loss 24.8344
# Epoch 133, batch 600, d_loss 0.0000 g_loss 24.8423
# Epoch 133, batch 900, d_loss 0.0000 g_loss 24.9001
# Epoch 134, batch 300, d_loss 0.0000 g_loss 25.0438
# Epoch 134, batch 600, d_loss 0.0000 g_loss 25.0004
# Epoch 134, batch 900, d_loss 0.0000 g_loss 24.9399
# Epoch 135, batch 300, d_loss 0.0000 g_loss 24.9438
# Epoch 135, batch 600, d_loss 0.0000 g_loss 25.0470
# Epoch 135, batch 900, d_loss 0.0000 g_loss 25.0242
# Epoch 136, batch 300, d_loss 0.0000 g_loss 25.0254
# Epoch 136, batch 600, d_loss 0.0000 g_loss 25.0643
# Epoch 136, batch 900, d_loss 0.0000 g_loss 25.1519
# Epoch 137, batch 300, d_loss 0.0000 g_loss 25.1885
# Epoch 137, batch 600, d_loss 0.0000 g_loss 21.9317
# Epoch 137, batch 900, d_loss 0.0000 g_loss 22.1730
# Epoch 138, batch 300, d_loss 0.0000 g_loss 23.0457
# Epoch 138, batch 600, d_loss 0.0000 g_loss 23.4547
# Epoch 138, batch 900, d_loss 0.0000 g_loss 23.0386
# Epoch 139, batch 300, d_loss 0.0000 g_loss 20.7312
# Epoch 139, batch 600, d_loss 0.0000 g_loss 20.4838
# Epoch 139, batch 900, d_loss 0.0000 g_loss 21.8492
# Epoch 140, batch 300, d_loss 0.0008 g_loss 6.4733
# Epoch 140, batch 600, d_loss 0.0000 g_loss 9.3134
# Epoch 140, batch 900, d_loss 0.0000 g_loss 9.3096
# Epoch 141, batch 300, d_loss 0.0000 g_loss 10.5947
# Epoch 141, batch 600, d_loss 0.0001 g_loss 10.9394
# Epoch 141, batch 900, d_loss 0.0000 g_loss 11.3161
# Epoch 142, batch 300, d_loss 0.0000 g_loss 11.7341
# Epoch 142, batch 600, d_loss 0.0000 g_loss 11.4856
# Epoch 142, batch 900, d_loss 0.0000 g_loss 12.1696
# Epoch 143, batch 300, d_loss 0.0000 g_loss 12.5100
# Epoch 143, batch 600, d_loss 0.0000 g_loss 12.1550
# Epoch 143, batch 900, d_loss 0.0000 g_loss 12.2133
# Epoch 144, batch 300, d_loss 0.0000 g_loss 12.6716
# Epoch 144, batch 600, d_loss 0.0000 g_loss 12.7729
# Epoch 144, batch 900, d_loss 0.0000 g_loss 12.6033
# Epoch 145, batch 300, d_loss 0.0000 g_loss 13.2138
# Epoch 145, batch 600, d_loss 0.0000 g_loss 13.5243
# Epoch 145, batch 900, d_loss 0.0000 g_loss 13.3270
# Epoch 146, batch 300, d_loss 0.0000 g_loss 13.5597
# Epoch 146, batch 600, d_loss 0.0000 g_loss 13.9889
# Epoch 146, batch 900, d_loss 0.0000 g_loss 13.9864
# Epoch 147, batch 300, d_loss 0.0000 g_loss 13.8136
# Epoch 147, batch 600, d_loss 0.0000 g_loss 14.1632
# Epoch 147, batch 900, d_loss 0.0000 g_loss 14.5020
# Epoch 148, batch 300, d_loss 0.0000 g_loss 14.2604
# Epoch 148, batch 600, d_loss 0.0000 g_loss 15.0108
# Epoch 148, batch 900, d_loss 0.0000 g_loss 14.8988
# Epoch 149, batch 300, d_loss 0.0000 g_loss 14.8768
# Epoch 149, batch 600, d_loss 0.0000 g_loss 15.2361
# Epoch 149, batch 900, d_loss 0.0000 g_loss 15.6649
# Epoch 150, batch 300, d_loss 0.0000 g_loss 15.2289
# Epoch 150, batch 600, d_loss 0.0000 g_loss 15.9090
# Epoch 150, batch 900, d_loss 0.0000 g_loss 15.7196
# Epoch 151, batch 300, d_loss 0.0000 g_loss 16.2896
# Epoch 151, batch 600, d_loss 0.0000 g_loss 15.7319
# Epoch 151, batch 900, d_loss 0.0000 g_loss 16.5100
# Epoch 152, batch 300, d_loss 0.0000 g_loss 16.6130
# Epoch 152, batch 600, d_loss 0.0000 g_loss 16.8263
# Epoch 152, batch 900, d_loss 0.0000 g_loss 16.7348
# Epoch 153, batch 300, d_loss 0.0004 g_loss 8.4153
# Epoch 153, batch 600, d_loss 0.0001 g_loss 9.0434
# Epoch 153, batch 900, d_loss 0.0000 g_loss 10.8889
# Epoch 154, batch 300, d_loss 0.0000 g_loss 10.7079
# Epoch 154, batch 600, d_loss 0.0000 g_loss 11.9146
# Epoch 154, batch 900, d_loss 0.0000 g_loss 11.7277
# Epoch 155, batch 300, d_loss 0.0000 g_loss 12.8109
# Epoch 155, batch 600, d_loss 0.0000 g_loss 12.8376
# Epoch 155, batch 900, d_loss 0.0003 g_loss 11.3876
# Epoch 156, batch 300, d_loss 0.0000 g_loss 12.0685
# Epoch 156, batch 600, d_loss 0.0000 g_loss 12.7939
# Epoch 156, batch 900, d_loss 0.0000 g_loss 13.4225
# Epoch 157, batch 300, d_loss 0.0000 g_loss 13.7830
# Epoch 157, batch 600, d_loss 0.0000 g_loss 13.7774
# Epoch 157, batch 900, d_loss 0.0000 g_loss 13.9729
# Epoch 158, batch 300, d_loss 0.0000 g_loss 14.2154
# Epoch 158, batch 600, d_loss 0.0000 g_loss 14.5632
# Epoch 158, batch 900, d_loss 0.0000 g_loss 14.4917
# Epoch 159, batch 300, d_loss 0.0000 g_loss 14.5659
# Epoch 159, batch 600, d_loss 0.0000 g_loss 14.8868
# Epoch 159, batch 900, d_loss 0.0000 g_loss 15.0256
# Epoch 160, batch 300, d_loss 0.0000 g_loss 15.5608
# Epoch 160, batch 600, d_loss 0.0000 g_loss 15.4882
# Epoch 160, batch 900, d_loss 0.0000 g_loss 15.7379
# Epoch 161, batch 300, d_loss 0.0000 g_loss 15.8029
# Epoch 161, batch 600, d_loss 0.0000 g_loss 16.0302
# Epoch 161, batch 900, d_loss 0.0000 g_loss 16.4734
# Epoch 162, batch 300, d_loss 0.0000 g_loss 16.5127
# Epoch 162, batch 600, d_loss 0.0000 g_loss 16.6429
# Epoch 162, batch 900, d_loss 0.0000 g_loss 16.5953
# Epoch 163, batch 300, d_loss 0.0000 g_loss 16.8360
# Epoch 163, batch 600, d_loss 0.0000 g_loss 16.9641
# Epoch 163, batch 900, d_loss 0.0000 g_loss 17.2943
# Epoch 164, batch 300, d_loss 0.0000 g_loss 17.1633
# Epoch 164, batch 600, d_loss 0.0000 g_loss 17.3252
# Epoch 164, batch 900, d_loss 0.0000 g_loss 17.7777
# Epoch 165, batch 300, d_loss 0.0000 g_loss 17.9847
# Epoch 165, batch 600, d_loss 0.0000 g_loss 17.9538
# Epoch 165, batch 900, d_loss 0.0000 g_loss 18.1270
# Epoch 166, batch 300, d_loss 0.0000 g_loss 18.2005
# Epoch 166, batch 600, d_loss 0.0000 g_loss 18.5275
# Epoch 166, batch 900, d_loss 0.0000 g_loss 18.4541
# Epoch 167, batch 300, d_loss 0.0000 g_loss 17.3672
# Epoch 167, batch 600, d_loss 0.0000 g_loss 16.6755
# Epoch 167, batch 900, d_loss 0.0000 g_loss 17.5305
# Epoch 168, batch 300, d_loss 0.0000 g_loss 17.9504
# Epoch 168, batch 600, d_loss 0.0000 g_loss 17.7001
# Epoch 168, batch 900, d_loss 0.0000 g_loss 17.3270
# Epoch 169, batch 300, d_loss 0.0000 g_loss 17.4616
# Epoch 169, batch 600, d_loss 0.0000 g_loss 18.2192
# Epoch 169, batch 900, d_loss 0.0000 g_loss 18.1850
# Epoch 170, batch 300, d_loss 0.0000 g_loss 18.4636
# Epoch 170, batch 600, d_loss 0.0000 g_loss 19.1706
# Epoch 170, batch 900, d_loss 0.0000 g_loss 18.8920
# Epoch 171, batch 300, d_loss 0.0000 g_loss 19.5674
# Epoch 171, batch 600, d_loss 0.0000 g_loss 19.5738
# Epoch 171, batch 900, d_loss 0.0000 g_loss 19.2369
# Epoch 172, batch 300, d_loss 0.0000 g_loss 19.8616
# Epoch 172, batch 600, d_loss 0.0000 g_loss 20.3065
# Epoch 172, batch 900, d_loss 0.0000 g_loss 19.9586
# Epoch 173, batch 300, d_loss 0.0000 g_loss 20.3739
# Epoch 173, batch 600, d_loss 0.0000 g_loss 20.4930
# Epoch 173, batch 900, d_loss 0.0000 g_loss 20.4060
# Epoch 174, batch 300, d_loss 0.0000 g_loss 20.6549
# Epoch 174, batch 600, d_loss 0.0000 g_loss 20.7725
# Epoch 174, batch 900, d_loss 0.0000 g_loss 21.1372
# Epoch 175, batch 300, d_loss 0.0000 g_loss 21.3487
# Epoch 175, batch 600, d_loss 0.0000 g_loss 21.3784
# Epoch 175, batch 900, d_loss 0.0000 g_loss 21.2447
# Epoch 176, batch 300, d_loss 0.0000 g_loss 21.5299
# Epoch 176, batch 600, d_loss 0.0000 g_loss 17.6667
# Epoch 176, batch 900, d_loss 0.0001 g_loss 8.2926
# Epoch 177, batch 300, d_loss 0.0001 g_loss 8.8906
# Epoch 177, batch 600, d_loss 0.0001 g_loss 9.5392
# Epoch 177, batch 900, d_loss 0.0000 g_loss 10.5054
# Epoch 178, batch 300, d_loss 0.0000 g_loss 10.3167
# Epoch 178, batch 600, d_loss 0.0000 g_loss 10.9583
# Epoch 178, batch 900, d_loss 0.0000 g_loss 11.1477
# Epoch 179, batch 300, d_loss 0.0000 g_loss 11.3263
# Epoch 179, batch 600, d_loss 0.0000 g_loss 11.5708
# Epoch 179, batch 900, d_loss 0.0000 g_loss 11.9831
# Epoch 180, batch 300, d_loss 0.0000 g_loss 11.9586
# Epoch 180, batch 600, d_loss 0.0001 g_loss 12.3205
# Epoch 180, batch 900, d_loss 0.0000 g_loss 12.3379
# Epoch 181, batch 300, d_loss 0.0000 g_loss 12.5888
# Epoch 181, batch 600, d_loss 0.0000 g_loss 12.7658
# Epoch 181, batch 900, d_loss 0.0000 g_loss 12.9415
# Epoch 182, batch 300, d_loss 0.0000 g_loss 13.1572
# Epoch 182, batch 600, d_loss 0.0000 g_loss 12.9345
# Epoch 182, batch 900, d_loss 0.0000 g_loss 13.2693
# Epoch 183, batch 300, d_loss 0.0000 g_loss 13.4608
# Epoch 183, batch 600, d_loss 0.0000 g_loss 13.6915
# Epoch 183, batch 900, d_loss 0.0000 g_loss 13.9612
# Epoch 184, batch 300, d_loss 0.0000 g_loss 14.0839
# Epoch 184, batch 600, d_loss 0.0000 g_loss 14.0887
# Epoch 184, batch 900, d_loss 0.0000 g_loss 14.3984
# Epoch 185, batch 300, d_loss 0.0000 g_loss 14.4898
# Epoch 185, batch 600, d_loss 0.0000 g_loss 14.7187
# Epoch 185, batch 900, d_loss 0.0000 g_loss 14.9302
# Epoch 186, batch 300, d_loss 0.0000 g_loss 15.0612
# Epoch 186, batch 600, d_loss 0.0000 g_loss 15.3198
# Epoch 186, batch 900, d_loss 0.0000 g_loss 15.1915
# Epoch 187, batch 300, d_loss 0.0000 g_loss 15.4805
# Epoch 187, batch 600, d_loss 0.0000 g_loss 15.5445
# Epoch 187, batch 900, d_loss 0.0000 g_loss 15.8145
# Epoch 188, batch 300, d_loss 0.0000 g_loss 16.1040
# Epoch 188, batch 600, d_loss 0.0000 g_loss 16.0640
# Epoch 188, batch 900, d_loss 0.0000 g_loss 16.2772
# Epoch 189, batch 300, d_loss 0.0000 g_loss 16.4961
# Epoch 189, batch 600, d_loss 0.0000 g_loss 16.5649
# Epoch 189, batch 900, d_loss 0.0000 g_loss 16.7932
# Epoch 190, batch 300, d_loss 0.0000 g_loss 16.7361
# Epoch 190, batch 600, d_loss 0.0000 g_loss 17.2046
# Epoch 190, batch 900, d_loss 0.0000 g_loss 17.2304
# Epoch 191, batch 300, d_loss 0.0000 g_loss 17.4271
# Epoch 191, batch 600, d_loss 0.0000 g_loss 17.4175
# Epoch 191, batch 900, d_loss 0.0000 g_loss 17.7303
# Epoch 192, batch 300, d_loss 0.0000 g_loss 17.8960
# Epoch 192, batch 600, d_loss 0.0000 g_loss 18.0511
# Epoch 192, batch 900, d_loss 0.0000 g_loss 18.1559
# Epoch 193, batch 300, d_loss 0.0000 g_loss 18.3241
# Epoch 193, batch 600, d_loss 0.0000 g_loss 18.4532
# Epoch 193, batch 900, d_loss 0.0000 g_loss 18.6784
# Epoch 194, batch 300, d_loss 0.0000 g_loss 18.8985
# Epoch 194, batch 600, d_loss 0.0000 g_loss 18.8800
# Epoch 194, batch 900, d_loss 0.0000 g_loss 19.0692
# Epoch 195, batch 300, d_loss 0.0000 g_loss 19.2983
# Epoch 195, batch 600, d_loss 0.0000 g_loss 19.4336
# Epoch 195, batch 900, d_loss 0.0000 g_loss 19.5243
# Epoch 196, batch 300, d_loss 0.0000 g_loss 19.6864
# Epoch 196, batch 600, d_loss 0.0000 g_loss 19.7397
# Epoch 196, batch 900, d_loss 0.0000 g_loss 20.0408
# Epoch 197, batch 300, d_loss 0.0000 g_loss 20.3115
# Epoch 197, batch 600, d_loss 0.0000 g_loss 20.2503
# Epoch 197, batch 900, d_loss 0.0000 g_loss 20.4485
# Epoch 198, batch 300, d_loss 0.0000 g_loss 20.7097
# Epoch 198, batch 600, d_loss 0.0000 g_loss 20.7828
# Epoch 198, batch 900, d_loss 0.0000 g_loss 20.8451
# Epoch 199, batch 300, d_loss 0.0000 g_loss 17.1620
# Epoch 199, batch 600, d_loss 0.0000 g_loss 20.5350
# Epoch 199, batch 900, d_loss 0.0022 g_loss 8.6229
